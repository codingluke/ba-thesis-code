# %%
import os, sys
lib_path = os.path.abspath(os.path.join('..', 'src'))
sys.path.append(lib_path)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# /home/lho/Htw/bachelor/thesis-code/venv/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from metric import MetricRecorder, MetricReader, plt
import matplotlib.patches as mpatches

# %%
mr = MetricReader(config_dir_path='../training/no_spearmint/simple.json')
m = MetricRecorder(config_dir_path='../training/no_spearmint/simple.json')

# %%
mr.get_job_metadata(85)
# Out:
#                         _id algorithm  dropouts  eta  eta_min  \
# 0  56c30bbff2684a4d8f5447bd   rmsprop  0.0, 0.0  0.1     0.01
#
#    improvement_threshold  job_id                layers  lmbda  \
# 0                  0.995      85  FC(25, 80)-FC(80, 1)      0
#
#    mini_batch_size  momentum  patience_increase random_mode  training_data  \
# 0              500      0.95                  2       fully        3486240
#
#    validation_data  validation_frequency
# 0          3486240                     3

# %%
mr.compair_plot([43,47,52, 51], 
                 colors=['r', 'g', 'b', 'k'], 
                titles=['Dropout: 0.0', 'Dropout: 0.1', 'Dropout: 0.05', 'Dropout: 0.01'])

# %%
mr.compair_plot([43, 52, 51])

# %%
mr.plot(43)

# %%
mr.compair_plot(job_ids=[47, 54, 43])

# %%
mr.compair_plot(job_ids=[42, 43, 44, 45, 46, 50], 
                titles=['500 Neuronen', '200 Neuronen','100 Neuronen','25 Neuronen', '21 Neuronen', '15 Neuronen'],
                colors=['g', 'b', 'k', 'r', 'y', 'm'],
                figsize=(9,3.5), xytext=(1.5, 0.05))
