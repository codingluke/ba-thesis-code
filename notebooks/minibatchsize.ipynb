# %%
import os, sys
lib_path = os.path.abspath(os.path.join('..', 'src'))
sys.path.append(lib_path)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# /home/lho/Htw/bachelor/thesis-code/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from metric import MetricRecorder, MetricReader, plt
import matplotlib.patches as mpatches

# %%
mr = MetricReader(config_dir_path='../training/no_spearmint/simple.json')
m = MetricRecorder(config_dir_path='../training/no_spearmint/simple.json')

# %%
mr.get_experiment_names()
# Out:
# [u'about',
#  u'system.indexes',
#  u'testcollection',
#  u'simple-braninhoo-example.jobs',
#  u'simple-braninhoo-example.hypers',
#  u'slp-1.jobs',
#  u'slp-1.hypers',
#  u'slp-test.jobs',
#  u'slp-2.jobs',
#  u'slp-2.hypers',
#  u'metric-test.jobs',
#  u'metric-test.hypers',
#  u'simple-net.jobs',
#  u'simple-all.jobs',
#  u'simple-all.hypers',
#  u'simple-ae.jobs',
#  u'simple-ae.hypers',
#  u'simple.trainings',
#  u'simple.metrics',
#  u'metric-test.metrics',
#  u'sdA-full.metrics',
#  u'sdA-full.trainings',
#  u'test-sae.metrics',
#  u'test-sae.trainings',
#  u'minibatch-size.metrics',
#  u'minibatch-size.trainings',
#  u'simple-ae.metrics',
#  u'simple-ae.trainings',
#  u'simple-all.metrics',
#  u'simple-all.trainings',
#  u'simple-net.trainings',
#  u'meta']

# %%
mr.compair_plot(job_ids=[31, 32, 33, 34, 35], 
                titles=['50bs - 998s/e', '100bs - 662s/e', '200bs - 450s/e', 
                        '500bs - 391s/e' , '1000 - 337s/e'], 
                colors=['r', 'g', 'b', 'k', 'y'], figsize=(9,3), xytext=(1.5, 0.04))
# Out:
# /home/lho/Htw/bachelor/thesis-code/venv/local/lib/python2.7/site-packages/pandas/tools/plotting.py:3283: UserWarning: When passing multiple axes, layout keyword is ignored
#   warnings.warn("When passing multiple axes, layout keyword is ignored", UserWarning)

# %%
mr.plot(job_id=41)
# Out:
# /home/lho/Htw/bachelor/thesis-code/venv/local/lib/python2.7/site-packages/pandas/tools/plotting.py:3303: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   "is being cleared", UserWarning)

# %%
mr.compair_plot(job_ids=[34, 36, 41], colors=['g', 'b', 'k'], titles=['rmsprop', 'sgd + momentum', 'l2'])
