# %%
import os, sys
lib_path = os.path.abspath(os.path.join('..', 'src'))
sys.path.append(lib_path)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from metric import MetricRecorder, MetricReader, plt
import matplotlib.patches as mpatches

# %%
mr = MetricReader(config_dir_path='../spearmint/simple/config.json')
m = MetricRecorder(config_dir_path='../spearmint/simple/config.json')

# %%
mr.plot(job_id=34)

# %%
mr.compair_plot(job_ids=[16, 33, 34])

# %%
#mr.db['simple-all']['jobs'].remove({'id':35})
# Out:
# {u'n': 1, u'ok': 1}

# %%
mr.db.collection_names()
# Out:
# [u'about',
#  u'system.indexes',
#  u'testcollection',
#  u'simple-braninhoo-example.jobs',
#  u'simple-braninhoo-example.hypers',
#  u'slp-1.jobs',
#  u'slp-1.hypers',
#  u'slp-test.jobs',
#  u'slp-2.jobs',
#  u'slp-2.hypers',
#  u'db.meta',
#  u'metric-test.jobs',
#  u'db.metric-test.metrics',
#  u'metric-test.hypers',
#  u'db.minibatch-size.metrics',
#  u'db.test-sae.metrics',
#  u'db.sdA-full.metrics',
#  u'db.sdA-full.trainings',
#  u'db.test-sae.trainings',
#  u'db.minibatch-size.trainings',
#  u'db.simple.trainings',
#  u'db.simple.metrics',
#  u'simple-net.jobs',
#  u'db.simple-net.trainings',
#  u'simple-all.jobs',
#  u'db.simple-all.trainings',
#  u'db.simple-all.metrics',
#  u'simple-all.hypers']
