# %%
import os, sys
lib_path = os.path.abspath(os.path.join('..', 'src'))
sys.path.append(lib_path)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from metric import MetricRecorder, MetricReader, plt
import matplotlib.patches as mpatches
# Out:
# /home/lho/Htw/bachelor/thesis-code/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
mr = MetricReader(config_dir_path='../tests/data/spearmin_config/config.json')

# %%
## Rename collections without db
#mr.db['db.metric-test.metrics'].rename('metric-test.metrics')
#mr.db['db.simple.trainings'].rename('simple.trainings')
#mr.db['db.simple.metrics'].rename('simple.metrics')
#mr.db['db.sdA-full.metrics'].rename('sdA-full.metrics')
#mr.db['db.sdA-full.trainings'].rename('sdA-full.trainings')
#mr.db['db.test-sae.metrics'].rename('test-sae.metrics')
#mr.db['db.test-sae.trainings'].rename('test-sae.trainings')
#mr.db['db.minibatch-size.metrics'].rename('minibatch-size.metrics')
#mr.db['db.minibatch-size.trainings'].rename('minibatch-size.trainings')
#mr.db['db.simple-ae.metrics'].rename('simple-ae.metrics')
#mr.db['db.simple-ae.trainings'].rename('simple-ae.trainings')
#mr.db['db.simple-all.metrics'].rename('simple-all.metrics')
#mr.db['db.simple-all.trainings'].rename('simple-all.trainings')
#mr.db['db.simple-net.trainings'].rename('simple-net.trainings')
#mr.db['db.meta'].rename('meta')

# %%
mr.get_job_metadata(job_id=50, experiment_name='metric-test')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
mr.plot(job_id=50, experiment_name='simple')

# %%
names = mr.db.collection_names()
names.sort()
names
# Out:
# [u'about',
#  u'meta',
#  u'metric-test.hypers',
#  u'metric-test.jobs',
#  u'metric-test.metrics',
#  u'minibatch-size.metrics',
#  u'minibatch-size.trainings',
#  u'sdA-full.metrics',
#  u'sdA-full.trainings',
#  u'simple-ae.hypers',
#  u'simple-ae.jobs',
#  u'simple-ae.metrics',
#  u'simple-ae.trainings',
#  u'simple-all.hypers',
#  u'simple-all.jobs',
#  u'simple-all.metrics',
#  u'simple-all.trainings',
#  u'simple-braninhoo-example.hypers',
#  u'simple-braninhoo-example.jobs',
#  u'simple-net.jobs',
#  u'simple-net.trainings',
#  u'simple.metrics',
#  u'simple.trainings',
#  u'slp-1.hypers',
#  u'slp-1.jobs',
#  u'slp-2.hypers',
#  u'slp-2.jobs',
#  u'slp-test.jobs',
#  u'system.indexes',
#  u'test-sae.metrics',
#  u'test-sae.trainings',
#  u'testcollection']
