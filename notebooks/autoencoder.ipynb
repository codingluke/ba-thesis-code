# %%
import os, sys
lib_path = os.path.abspath(os.path.join('..', 'src'))
sys.path.append(lib_path)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# /home/lho/Htw/bachelor/thesis-code/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from metric import MetricRecorder, MetricReader, plt
import matplotlib.patches as mpatches

# %%
jobs = mr.db['sda3.jobs']
metrics = mr.db['sda3.metrics']
trainings = mr.db['sda3.trainings']
hypers = mr.db['sda3.hypers']

# %%
#trainings.remove({'job_id' : 10})
# Out:
# {u'n': 0, u'ok': 1}

# %%
rm.

# %%
mr.plot(1, experiment_name='sda4')

# %%
mr.get_records(4, experiment_name='sda2', typ='train')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
mr = MetricReader(config_dir_path='../training/no_spearmint/simple.json')
m = MetricRecorder(config_dir_path='../training/no_spearmint/simple.json')

# %%
mr.plot(2, experiment_name='sda2')

# %%
mr.plot(15, experiment_name='sdA-full')
# Out:
# /home/lho/Htw/bachelor/thesis-code/venv/local/lib/python2.7/site-packages/pandas/tools/plotting.py:3303: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   "is being cleared", UserWarning)

# %%
mr.compair_plot([35, 16, 15], experiment_names=['simple-ae', 'sdA-full', 'sdA-full'], 
                titles=['Einschichtiger dA','sdA ohne Voraustraining', 'sdA mit Voraustraining' ],
                figsize=(9,4), xytext=(6,0.022))

# %%
mr.plot(15, experiment_name='sdA-full')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-14c6a3f38257> in <module>()
# ----> 1 mr.plot(15, experiment_name='sdA-full')
#
# NameError: name 'mr' is not defined

# %% [markdown]
# 62: Autoencoder 12 pretraining Epochen
# 63: normal aber mehr Epochen
# 64: Mit trainings data als pretraindata
# 65: Autoencoder 15 pretraining 0.3 corruption -> Missgeburt... zwei trainings auf das selbe :(
# 66: -
# 67: Autoencoder 15 pretraining 0.1 -> 0.02673
# 68: Autoencoder border 3, 0.2 corruption
# 69: Autoencoder 15 pretraining 0.2
# 71: Autoencoder 12 pretrain, middle trainset
# 72: Autoencoder 10 pretrain eta 0.015, corruption 0.2, 10 epoches

# %%
mr.compair_plot([63, 72])

# %%
mr.compair_plot([29, 55, 56], figsize=(15,9))
